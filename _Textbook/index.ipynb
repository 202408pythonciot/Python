# %% [markdown]
# # Python基礎
# ## 第１章
# - 1.1 Pythonの概要
# - 1.2 プログラムの動作
#
# ## 第２章
# - 2.1 Pythonの実行環境
# - 2.2 Visual Studio Codeの環境構築
#
# ## 第３章
# - 3.1 ファイルから実行する方法
# - 3.2 インタラクティブシェルで実行する方法
# - 3.3 Pythonのソースコード記述時の注意点
#
# ## 第４章
# - 4.1 変数
# - 4.2 型と演算
# - 4.3 テキストシーケンス
#
# ## 第５章
# - 5.1 条件分岐
# - 5.2 for ループ
# - 5.3 while ループ
# - 5.4 break と continue
#
# ## 第６章
# - 6.1 コレクションの概要
# - 6.2 リスト（list）
# - 6.3 タプル（tuple）
# - 6.4 テキストシーケンス（str）
# - 6.5 セット（set）
# - 6.6 マップ（dict）
#
# ## 第７章 関数
# - 7.1 関数
# - 7.2 変数のスコープ
# - 7.3 関数の高度な利用方法
#
# ## 第８章 クラス
# - 8.1 オブジェクト指向とは
# - 8.2 クラスの基本
# - 8.3 高度なクラスの利用方法
# - 8.4 クラスの特殊事情
#
# ## 第９章
# - 9.1 モジュールとは
# - 9.2 パッケージ
#
# ## 第１０章 例外処理
# - 10.1 例外処理とは
